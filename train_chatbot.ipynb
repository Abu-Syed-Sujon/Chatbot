# %% [markdown]
# <h1>Import Libraries</h1>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

import json
import pickle
# Out:
# WARNING:tensorflow:From c:\Users\Sujon\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <h1>Load the Data</h1>

# %%
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %% [markdown]
# <h1>Preprocessing the Data</h1>

# %%
import nltk
nltk.download('punkt')

words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # Tokenize each word
        tokenized_words = nltk.word_tokenize(pattern)
        words.extend(tokenized_words)   
        
        # Add documents in the corpus
        documents.append((tokenized_words, intent['tag']))
        
        # Add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

print(documents)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sujon\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %% [markdown]
# <h1>Lemmatize each word and remove the duplicate words</h1>

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import pickle

# Ensure 'punkt' and 'wordnet' resources are available
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

try:
    nltk.data.find('corpora/wordnet')
except LookupError:
    nltk.download('wordnet')

# Initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

# Your pre-existing lists
words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

# Assuming you already have 'intents' dictionary populated from previous steps
for intent in intents['intents']:
    for pattern in intent['patterns']:
        # Tokenize each word
        tokenized_words = nltk.word_tokenize(pattern)
        words.extend(tokenized_words)
        documents.append((tokenized_words, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))

# Sort classes
classes = sorted(list(set(classes)))

# Print results
print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)

# Save words and classes to pickle files
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sujon\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# <h1>Create Training and Testing Data</h1>

# %%
# create the training data
training = []
output = []
# create empty array for the output
output_empty = np.zeros((len(classes),))

# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = np.zeros((len(words),))
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in an attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    # create the bag of words array with 1, if the word is found in the current pattern
    for i, word in enumerate(words):
        bag[i] = 1 if word in word_patterns else 0
    
    # output is a '0' for each tag and '1' for the current tag (for each pattern)
    output_row = output_empty.copy()
    output_row[classes.index(doc[1])] = 1
    training.append(bag)
    output.append(output_row)

# convert lists to numpy arrays
training = np.array(training)
output = np.array(output)

# shuffle the features and make a numpy array
indices = np.arange(training.shape[0])
np.random.shuffle(indices)
training = training[indices]
output = output[indices]

# create training and testing lists. X - patterns, Y - intents
train_x = training
train_y = output

print("Training data is created")
# Out:
# Training data is created

# %% [markdown]
# <h1>Create Model</h1>

# %%
# deep neural networds model

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Out:
# WARNING:tensorflow:From c:\Users\Sujon\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# <h1>Compile the model</h1>

# %%
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# Define an exponential decay learning rate schedule
initial_learning_rate = 0.01
lr_schedule = ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_steps=1000,  # Number of steps before applying decay
    decay_rate=0.96,   # Decay rate
    staircase=True     # If True, the learning rate is decayed at discrete intervals
)

# Initialize the SGD optimizer with the learning rate schedule
sgd = SGD(learning_rate=lr_schedule, momentum=0.9, nesterov=True)

# Compile the model with categorical crossentropy loss and the SGD optimizer
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %% [markdown]
# <h1>Training the Model</h1>

# %%
#Training and saving the model 

hist = model.fit(np.array(train_x), 
                 np.array(train_y), 
                 epochs=300, 
                 batch_size=5, 
                 verbose=1)

model.save('chatbot_model.h5', hist)

print("model is created")
# Out:
# Epoch 1/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9787
# Epoch 2/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 3/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.9787
# Epoch 4/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 5/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9787
# Epoch 6/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 7/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 8/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 9/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 0.9787
# Epoch 10/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9787
# Epoch 11/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 12/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 13/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 14/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 0.9787
# Epoch 15/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 16/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0521 - accuracy: 0.9787
# Epoch 17/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 0.9787
# Epoch 18/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 19/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 0.9787
# Epoch 20/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 21/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 22/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0467 - accuracy: 0.9787
# Epoch 23/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 24/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 25/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 26/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 27/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 28/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 29/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 30/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 31/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 32/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 33/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1327 - accuracy: 0.9574
# Epoch 34/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 35/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9362
# Epoch 36/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 0.9787
# Epoch 37/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 38/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 39/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 40/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0603 - accuracy: 0.9574
# Epoch 41/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9787
# Epoch 42/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 43/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 44/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 45/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 46/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 47/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0624 - accuracy: 0.9787
# Epoch 48/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 49/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 50/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 51/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 52/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 53/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 54/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9787
# Epoch 55/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.9787
# Epoch 56/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 57/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 58/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.9574
# Epoch 59/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0914 - accuracy: 0.9787
# Epoch 60/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9787
# Epoch 61/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 62/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 63/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 64/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9787
# Epoch 65/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0337 - accuracy: 0.9787
# Epoch 66/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 67/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9787
# Epoch 68/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 69/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 70/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 71/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 72/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 73/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 74/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 75/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 76/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 77/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 78/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 79/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 80/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 81/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 82/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 0.9787
# Epoch 83/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9787
# Epoch 84/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 85/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 86/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 87/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9787
# Epoch 88/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0558 - accuracy: 0.9787
# Epoch 89/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 90/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 91/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0561 - accuracy: 0.9787
# Epoch 92/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 93/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 94/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 95/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 96/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 97/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 98/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 99/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 0.9787
# Epoch 100/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 101/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 102/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 103/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 104/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 105/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 106/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 107/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 108/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 109/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 110/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 111/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 112/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 113/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 114/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 115/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9574
# Epoch 116/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 117/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 118/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 0.9787
# Epoch 119/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9787
# Epoch 120/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9787
# Epoch 121/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 122/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 123/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 124/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9787
# Epoch 125/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 126/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 127/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 128/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 129/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 130/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 0.9787
# Epoch 131/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 132/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 133/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 134/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9787
# Epoch 135/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 0.9787
# Epoch 136/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 137/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 138/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9787
# Epoch 139/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 140/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 141/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 142/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 143/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 144/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 145/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 146/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 147/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 148/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 149/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 150/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 151/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 152/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 153/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 154/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 155/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 156/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9787
# Epoch 157/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 158/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 159/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 160/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 161/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 162/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 163/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 164/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 165/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 166/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 167/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 168/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 169/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 170/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 171/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 172/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0446 - accuracy: 0.9787
# Epoch 173/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 174/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 175/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 176/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9787
# Epoch 177/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 178/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 179/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 180/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 181/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 182/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 183/300
# 10/10 [==============================] - 0s 4ms/step - loss: 3.7838e-04 - accuracy: 1.0000
# Epoch 184/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 185/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 186/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 187/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 188/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9787
# Epoch 189/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 190/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 191/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0396 - accuracy: 0.9787
# Epoch 192/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 193/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 194/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 195/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 196/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9787
# Epoch 197/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 198/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 199/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 200/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 201/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 202/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 203/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9787
# Epoch 204/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 205/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 206/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9787
# Epoch 207/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 208/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9574
# Epoch 209/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 210/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 211/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 212/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 213/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.9787
# Epoch 214/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9787
# Epoch 215/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 216/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 217/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 218/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 219/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9787
# Epoch 220/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 221/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 222/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 223/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 224/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 225/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 226/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 227/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 228/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 229/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 230/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 231/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 232/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 233/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 234/300
# 10/10 [==============================] - 0s 3ms/step - loss: 6.2892e-04 - accuracy: 1.0000
# Epoch 235/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 236/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 237/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 238/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 239/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 240/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 241/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 242/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 243/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 244/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 245/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 246/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 247/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 248/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 249/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 250/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9787
# Epoch 251/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 252/300
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 253/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0703 - accuracy: 0.9787
# Epoch 254/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 255/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 256/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9787
# Epoch 257/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 258/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 259/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 260/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 261/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 262/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 263/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 264/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 265/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 266/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 267/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 268/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9787
# Epoch 269/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 270/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 271/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 272/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 273/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 274/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 275/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 276/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 277/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0289 - accuracy: 0.9787
# Epoch 278/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 279/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 280/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 281/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 282/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 283/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0885 - accuracy: 0.9787
# Epoch 284/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 285/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 286/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 287/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 288/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 289/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 290/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 291/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 292/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 293/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 294/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 295/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 296/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 297/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 298/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 299/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 300/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# model is created
